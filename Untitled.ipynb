# %% [markdown]
# # Predicting Bulldozer Prices Using Regression on Time-Series Data

# %% [markdown]
# In this project we're going to run through an example of an ML project with a goal of predicting the sale price of bulldozers.
#
# https://www.kaggle.com/competitions/bluebook-for-bulldozers

# %% [markdown]
# ## 1. Project Definition
# How well can we predict the future sale price of a bulldozer given its characteristics and previous examples of sales data?

# %% [markdown]
# ## 2. Data
# We've grabbed data from an old Kaggle competition.
# * Train data - collected through 2011
# * Validation data - collected from Jan 2012 to April 2012
# * Test data - collected from May 2012 to November 2012

# %% [markdown]
# ## 3. Evaluation
# The evaluation metric for this project is the RMSLE (root mean squared log error) between the actual and predicted auction prices.

# %% [markdown]
# ## 4. Features
# The key fields are in train.csv are:
#
# * SalesID: the uniue identifier of the sale
# * MachineID: the unique identifier of a machine.  A machine can be sold multiple times
# * saleprice: what the machine sold for at auction (only provided in train.csv)
# * saledate: the date of the sale
#
# There are several fields towards the end of the file on the different options a machine can have.  The descriptions all start with "machine configuration" in the data dictionary.  Some product types do not have a particular option, so all the records for that option variable will be null for that product type.  Also, some sources do not provide good option and/or hours data.
#
# The machine_appendix.csv file contains the correct year manufactured for a given machine along with the make, model, and product class details. There is one machine id for every machine in all the competition datasets (training, evaluation, etc.).

# %% [markdown]
# ## 5. Modeling

# %% [markdown]
# ### 5.1 Import our tools and data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import training and validation datasets

df = pd.read_csv("TrainAndValid.csv", low_memory = False)

# %% [markdown]
# ### 5.2 Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
df.describe().T
# Out:
#                              count          mean           std        min  \
# SalesID                   412698.0  2.011161e+06  1.080068e+06  1139246.0
# SalePrice                 412698.0  3.121518e+04  2.314174e+04     4750.0
# MachineID                 412698.0  1.230061e+06  4.539533e+05        0.0
# ModelID                   412698.0  6.947202e+03  6.280825e+03       28.0
# datasource                412698.0  1.351694e+02  9.646749e+00      121.0
# auctioneerID              392562.0  6.585268e+00  1.715841e+01        0.0
# YearMade                  412698.0  1.899050e+03  2.921902e+02     1000.0
# MachineHoursCurrentMeter  147504.0  3.522988e+03  2.716993e+04        0.0
#
#                                  25%        50%         75%        max
# SalesID                   1421897.75  1645852.5  2261012.50  6333349.0
# SalePrice                   14500.00    24000.0    40000.00   142000.0
# MachineID                 1088593.25  1284397.0  1478079.25  2486330.0
# ...

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %%
df.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                  66000.0
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# saledate                                           11/16/2006 0:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...

# %%
plt.figure(figsize = (10, 8), dpi = 250)
df.SalePrice.plot.hist(bins = 50)
plt.title('Histogram of Price of Bulldozers')
plt.xlabel('Price ($)')
plt.show();

# %%
plt.figure(figsize = (5, 4), dpi = 150)
df.YearMade.plot.hist(bins = 50)
plt.title('Histogram of Year Made of Bulldozers')
plt.xlabel('Year')
plt.show();

# %% [markdown]
# **These bulldozers that are listed as being made in the year 1000 are going to have to be handled later.**

# %% [markdown]
# ### 5.3 Parsing Dates
#
# When working with time series data it's important to enrich the time and date components of the data as much as you can.
#
# We're going to do that by informing pandas which of the columns contain dates using the `parse_dates` parameter.

# %%
# Re-import the data to parse dates

df = pd.read_csv("TrainAndValid.csv",
                 low_memory=False,
                 parse_dates=["saledate"])

# %%
df.saledate.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# The dtype `<M8[ns]` is the datatype code for datetime64

# %% [markdown]
# ### 5.4 Feature Engineering
#
# **Add datetime parameters for `saledate` column and copy dataframe**

# %%
df_tmp = df.copy()

# %%
df_tmp["saleYear"] = df_tmp.saledate.dt.year
df_tmp["saleMonth"] = df_tmp.saledate.dt.month
df_tmp["saleDay"] = df_tmp.saledate.dt.day
df_tmp["saleDayOfWeek"] = df_tmp.saledate.dt.dayofweek
df_tmp["saleDayOfYear"] = df_tmp.saledate.dt.dayofyear

# %%
df_tmp.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                  66000.0
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# saledate                                       2006-11-16 00:00:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...

# %%
# Let's drop saledate as the information has been preserved

df_tmp.drop("saledate", axis=1, inplace=True)

# %% [markdown]
# ### 5.5 Convert Data to Appropriate Data Types

# %%
pd.api.types.is_string_dtype(df_tmp["UsageBand"])
# Out:
# False

# %%
df_tmp.dtypes
# Out:
# SalesID                       int64
# SalePrice                   float64
# MachineID                     int64
# ModelID                       int64
# datasource                    int64
# auctioneerID                float64
# YearMade                      int64
# MachineHoursCurrentMeter    float64
# UsageBand                    object
# fiModelDesc                  object
# fiBaseModel                  object
# fiSecondaryDesc              object
# fiModelSeries                object
# fiModelDescriptor            object
# ProductSize                  object
# fiProductClassDesc           object
# state                        object
# ProductGroup                 object
# ProductGroupDesc             object
# Drive_System                 object
# Enclosure                    object
# Forks                        object
# Pad_Type                     object
# Ride_Control                 object
# Stick                        object
# Transmission                 object
# ...

# %%
# Find the columns that contain strings

columns_to_convert = []

for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        columns_to_convert.append(label)
        print(label)
# Out:
# fiModelDesc
# fiBaseModel
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc

# %%
# Convert these columns into category values

for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   fiModelDesc               412698 non-null  category
#  10  fiBaseModel               412698 non-null  category
#  11  fiSecondaryDesc           271971 non-null  object
#  12  fiModelSeries             58667 non-null   object
# ...

# %%
df_tmp.state.cat.categories
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Unspecified', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'Washington DC', 'West Virginia', 'Wisconsin',
#        'Wyoming'],
#       dtype='object')

# %%
df_tmp.state.value_counts()[:10]
# Out:
# state
# Florida        67320
# Texas          53110
# California     29761
# Washington     16222
# Georgia        14633
# Maryland       13322
# Mississippi    13240
# Ohio           12369
# Illinois       11540
# Colorado       11529
# Name: count, dtype: int64

# %%
df_tmp.state.cat.codes
# Out:
# 0          0
# 1         32
# 2         31
# 3         43
# 4         31
#           ..
# 412693    43
# 412694     8
# 412695     8
# 412696    43
# 412697     8
# Length: 412698, dtype: int8

# %% [markdown]
# ****Save preprocessed data****

# %%
# Export current temporary dataframe

df_tmp.to_csv("train_tmp.csv",
             index=False)

# %%
# Import preprocessed data

df_tmp = pd.read_csv("train_tmp.csv",
                     low_memory=False)

df_tmp.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                  66000.0
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# fiModelSeries                                                  NaN
# ...

# %% [markdown]
# ## 5.6 Missing Values
# **We still have quite a bit of missing/erroneous data to deal with.**
#
# **Let's begin with missing numerical data**

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# SalesID
# SalePrice
# MachineID
# ModelID
# datasource
# auctioneerID
# YearMade
# MachineHoursCurrentMeter
# saleYear
# saleMonth
# saleDay
# saleDayOfWeek
# saleDayOfYear

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum() > 0:
            print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter

# %%
# Fill numeric missing values with the median value of the column and add another column which indicates the data was missing

for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum() > 0:
            # Add a column to indicate missing data
            df_tmp[label+"_is_missing"] = pd.isnull(content)
            
            # Fill missing value with median
            df_tmp[label] = content.fillna(content.median())

# %%
# Let's check if we have any null values in numeric columns

for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
        else:
            print("None!")
# Out:
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!
# None!

# %%
df_tmp.isna().sum()
# Out:
# SalesID                                     0
# SalePrice                                   0
# MachineID                                   0
# ModelID                                     0
# datasource                                  0
# auctioneerID                                0
# YearMade                                    0
# MachineHoursCurrentMeter                    0
# UsageBand                              339028
# fiModelDesc                                 0
# fiBaseModel                                 0
# fiSecondaryDesc                        140727
# fiModelSeries                          354031
# fiModelDescriptor                      337882
# ProductSize                            216605
# fiProductClassDesc                          0
# state                                       0
# ProductGroup                                0
# ProductGroupDesc                            0
# Drive_System                           305611
# ...

# %%
df['YearMade'].describe()
# Out:
# count    412698.000000
# mean       1899.049637
# std         292.190243
# min        1000.000000
# 25%        1985.000000
# 50%        1995.000000
# 75%        2001.000000
# max        2014.000000
# Name: YearMade, dtype: float64

# %%
sum(df.YearMade == 1000)
# Out:
# 39391

# %%
df[df.duplicated('MachineID')]
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 784     1141815    10000.0     157544     7009         121           3.0
# 1690    1144859   112000.0       8912    23926         121           3.0
# 2089    1146216     8500.0    1045793     6270         121           3.0
# 2165    1146491    10000.0    1023901     5282         121           3.0
# 2372    1147187    77000.0     895745     1636         121           3.0
# ...         ...        ...        ...      ...         ...           ...
# 412615  6328092    16000.0    1654874    20102         149          99.0
# 412618  6328105    18000.0    1821627    20102         149           0.0
# 412631  6328170    17500.0    1935044    20103         149           2.0
# 412634  6328178    18500.0    1841848    20103         149           1.0
# 412664  6333206    13000.0    1864521    21438         149           2.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand        saledate  ...  \
# ...
